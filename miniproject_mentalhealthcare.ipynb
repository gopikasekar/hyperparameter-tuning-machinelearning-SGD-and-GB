# %%
import pandas as pd

# %%
mental_health_data = pd.read_csv('Mental_Health_Dataset.csv')

# %%
mental_health_data
# Out:
#               Timestamp  Gender        Country Occupation self_employed  \
# 0       8/27/2014 11:29  Female  United States  Corporate           NaN
# 1       8/27/2014 11:31  Female  United States  Corporate           NaN
# 2       8/27/2014 11:32  Female  United States  Corporate           NaN
# 3       8/27/2014 11:37  Female  United States  Corporate            No
# 4       8/27/2014 11:43  Female  United States  Corporate            No
# ...                 ...     ...            ...        ...           ...
# 292359  7/27/2015 23:25    Male  United States   Business           Yes
# 292360   8/17/2015 9:38    Male   South Africa   Business            No
# 292361  8/25/2015 19:59    Male  United States   Business            No
# 292362   9/26/2015 1:07    Male  United States   Business            No
# 292363   2/1/2016 23:04    Male  United States   Business            No
#
#        family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0                  No       Yes    1-14 days            Yes             No
# 1                 Yes       Yes    1-14 days            Yes             No
# 2                 Yes       Yes    1-14 days            Yes             No
# 3                 Yes       Yes    1-14 days            Yes             No
# 4                 Yes       Yes    1-14 days            Yes             No
# ...               ...       ...          ...            ...            ...
# 292359            Yes       Yes   15-30 days             No          Maybe
# 292360            Yes       Yes   15-30 days             No          Maybe
# 292361            Yes        No   15-30 days             No          Maybe
# 292362            Yes       Yes   15-30 days             No          Maybe
# 292363            Yes       Yes   15-30 days             No          Maybe
#
#        Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                        Yes      Medium               No            No
# 1                        Yes      Medium               No            No
# 2                        Yes      Medium               No            No
# 3                        Yes      Medium               No            No
# 4                        Yes      Medium               No            No
# ...                      ...         ...              ...           ...
# 292359                    No         Low              Yes            No
# 292360                    No         Low              Yes            No
# 292361                    No         Low              Yes            No
# 292362                    No         Low              Yes            No
# 292363                    No         Low              Yes            No
#
#        Social_Weakness mental_health_interview care_options
# 0                  Yes                      No     Not sure
# 1                  Yes                      No           No
# 2                  Yes                      No          Yes
# 3                  Yes                   Maybe          Yes
# 4                  Yes                      No          Yes
# ...                ...                     ...          ...
# 292359           Maybe                   Maybe     Not sure
# 292360           Maybe                      No          Yes
# 292361           Maybe                      No           No
# 292362           Maybe                      No          Yes
# 292363           Maybe                      No          Yes
#
# [292364 rows x 17 columns]

# %%
column=mental_health_data.columns.tolist()

# %%
for i in column:
    print(mental_health_data[i].unique())
# Out:
# ['8/27/2014 11:29' '8/27/2014 11:31' '8/27/2014 11:32' '8/27/2014 11:37'
#  '8/27/2014 11:43' '8/27/2014 11:49' '8/27/2014 11:51' '8/27/2014 11:52'
#  '8/27/2014 12:18' '8/27/2014 12:37' '8/27/2014 12:39' '8/27/2014 12:40'
#  '8/27/2014 12:49' '8/27/2014 12:50' '8/27/2014 12:51' '8/27/2014 12:53'
#  '8/27/2014 12:55' '8/27/2014 12:57' '8/27/2014 13:06' '8/27/2014 13:31'
#  '8/27/2014 13:47' '8/27/2014 13:49' '8/27/2014 13:55' '8/27/2014 14:11'
#  '8/27/2014 14:13' '8/27/2014 14:16' '8/27/2014 14:19' '8/27/2014 14:27'
#  '8/27/2014 14:31' '8/27/2014 14:52' '8/27/2014 15:22' '8/27/2014 15:24'
#  '8/27/2014 15:29' '8/27/2014 15:34' '8/27/2014 15:35' '8/27/2014 15:36'
#  '9/11/2014 17:00' '9/13/2014 7:52' '9/14/2014 9:04' '9/23/2014 20:05'
#  '11/16/2014 8:42' '12/15/2014 0:43' '2/21/2015 4:16' '2/21/2015 4:41'
#  '2/21/2015 4:55' '2/21/2015 5:34' '2/21/2015 5:55' '2/21/2015 6:19'
#  '2/21/2015 8:21' '2/21/2015 8:54' '2/21/2015 9:19' '2/21/2015 9:22'
#  '2/21/2015 9:30' '2/21/2015 9:48' '2/21/2015 10:00' '2/21/2015 17:19'
#  '2/21/2015 18:59' '2/22/2015 2:40' '2/24/2015 9:00' '2/24/2015 9:13'
#  '2/24/2015 9:18' '2/24/2015 10:32' '4/2/2015 15:47' '4/11/2015 14:35'
#  '4/23/2015 14:03' '5/6/2015 10:14' '5/6/2015 16:55' '7/27/2015 23:25'
#  '8/17/2015 9:38' '8/25/2015 19:59' '9/26/2015 1:07' '2/1/2016 23:04']
# ['Female' 'Male']
# ['United States' 'Poland' 'Australia' 'Canada' 'United Kingdom'
#  'South Africa' 'Sweden' 'New Zealand' 'Netherlands' 'India' 'Belgium'
#  'Ireland' 'France' 'Portugal' 'Brazil' 'Costa Rica' 'Russia' 'Germany'
#  'Switzerland' 'Finland' 'Israel' 'Italy' 'Bosnia and Herzegovina'
#  'Singapore' 'Nigeria' 'Croatia' 'Thailand' 'Denmark' 'Mexico' 'Greece'
#  'Moldova' 'Colombia' 'Georgia' 'Czech Republic' 'Philippines']
# ['Corporate' 'Student' 'Business' 'Housewife' 'Others']
# [nan 'No' 'Yes']
# ['No' 'Yes']
# ['Yes' 'No']
# ['1-14 days' 'Go out Every day' 'More than 2 months' '15-30 days'
#  '31-60 days']
# ['Yes' 'No' 'Maybe']
# ['No' 'Yes' 'Maybe']
# ['Yes' 'No' 'Maybe']
# ['Medium' 'Low' 'High']
# ['No' nan 'Yes']
# ['No' 'Maybe' 'Yes']
# ['Yes' 'No' 'Maybe']
# ['No' 'Maybe' 'Yes' nan]
# ['Not sure' 'No' 'Yes']

# %%
mental_health_data['self_employed'].unique()
# Out:
# array([nan, 'No', 'Yes'], dtype=object)

# %%
mental_health_data.shape
# Out:
# (292364, 17)

# %%
mental_health_data.isnull().sum()
# Out:
# Timestamp                     0
# Gender                        0
# Country                       0
# Occupation                    0
# self_employed              5202
# family_history                0
# treatment                     0
# Days_Indoors                  0
# Growing_Stress                0
# Changes_Habits                0
# Mental_Health_History         0
# Mood_Swings                   0
# Coping_Struggles              1
# Work_Interest                 0
# Social_Weakness               0
# mental_health_interview       3
# care_options                  0
# dtype: int64

# %%
import numpy as np
mental_health_data.drop_duplicates(inplace= True)

# %%
mental_health_data.shape
# Out:
# (290051, 17)

# %%
mental_health_data.isnull().sum()
# Out:
# Timestamp                     0
# Gender                        0
# Country                       0
# Occupation                    0
# self_employed              5193
# family_history                0
# treatment                     0
# Days_Indoors                  0
# Growing_Stress                0
# Changes_Habits                0
# Mental_Health_History         0
# Mood_Swings                   0
# Coping_Struggles              1
# Work_Interest                 0
# Social_Weakness               0
# mental_health_interview       3
# care_options                  0
# dtype: int64

# %%
mental_health_data.dropna(inplace=True)

# %%
mental_health_data.shape
# Out:
# (284854, 17)

# %%
284854 - 292364
# Out:
# -7510

# %%
mental_health_data
# Out:
#               Timestamp  Gender        Country Occupation self_employed  \
# 3       8/27/2014 11:37  Female  United States  Corporate            No
# 4       8/27/2014 11:43  Female  United States  Corporate            No
# 5       8/27/2014 11:49  Female         Poland  Corporate            No
# 6       8/27/2014 11:51  Female      Australia  Corporate            No
# 7       8/27/2014 11:52  Female  United States  Corporate            No
# ...                 ...     ...            ...        ...           ...
# 292359  7/27/2015 23:25    Male  United States   Business           Yes
# 292360   8/17/2015 9:38    Male   South Africa   Business            No
# 292361  8/25/2015 19:59    Male  United States   Business            No
# 292362   9/26/2015 1:07    Male  United States   Business            No
# 292363   2/1/2016 23:04    Male  United States   Business            No
#
#        family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 3                 Yes       Yes    1-14 days            Yes             No
# 4                 Yes       Yes    1-14 days            Yes             No
# 5                  No       Yes    1-14 days            Yes             No
# 6                 Yes       Yes    1-14 days            Yes             No
# 7                  No        No    1-14 days            Yes             No
# ...               ...       ...          ...            ...            ...
# 292359            Yes       Yes   15-30 days             No          Maybe
# 292360            Yes       Yes   15-30 days             No          Maybe
# 292361            Yes        No   15-30 days             No          Maybe
# 292362            Yes       Yes   15-30 days             No          Maybe
# 292363            Yes       Yes   15-30 days             No          Maybe
#
#        Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 3                        Yes      Medium               No            No
# 4                        Yes      Medium               No            No
# 5                        Yes      Medium               No            No
# 6                        Yes      Medium               No            No
# 7                        Yes      Medium               No            No
# ...                      ...         ...              ...           ...
# 292359                    No         Low              Yes            No
# 292360                    No         Low              Yes            No
# 292361                    No         Low              Yes            No
# 292362                    No         Low              Yes            No
# 292363                    No         Low              Yes            No
#
#        Social_Weakness mental_health_interview care_options
# 3                  Yes                   Maybe          Yes
# 4                  Yes                      No          Yes
# 5                  Yes                   Maybe     Not sure
# 6                  Yes                      No     Not sure
# 7                  Yes                      No           No
# ...                ...                     ...          ...
# 292359           Maybe                   Maybe     Not sure
# 292360           Maybe                      No          Yes
# 292361           Maybe                      No           No
# 292362           Maybe                      No          Yes
# 292363           Maybe                      No          Yes
#
# [284854 rows x 17 columns]

# %%
mental_health_data.drop(columns='Timestamp',inplace=True)

# %%
mental_health_data.shape
# Out:
# (284854, 16)

# %%
col=mental_health_data.columns

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
encoder = LabelEncoder()

# Apply encoding to all columns
df_enc =pd.DataFrame( mental_health_data.apply(lambda col: encoder.fit_transform(col) if col.dtypes == 'object' else col))

df_enc
print("AFTER LABEL ENCODING:")
column=df_enc.columns.tolist()
for i in column:
    print(df_enc[i].unique())
# Out:
# AFTER LABEL ENCODING:
# [0 1]
# [34 25  0  4 33 29 30 22 21 15  1 16 11 26  3  6 27 13 31 10 17 18  2 28
#  23  7 32  9 19 14 20  5 12  8 24]
# [1 4 0 2 3]
# [0 1]
# [1 0]
# [1 0]
# [0 3 4 1 2]
# [2 1 0]
# [1 2 0]
# [2 1 0]
# [2 1 0]
# [0 1]
# [1 0 2]
# [2 1 0]
# [0 1 2]
# [2 1 0]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, roc_auc_score
import seaborn as sns
plt.figure(figsize=(15,10))
sns.heatmap(df_enc.corr(),annot=True)
plt.show()

# %%
X = df_enc.drop(columns='treatment')
y = df_enc['treatment']
from sklearn.feature_selection import RFE

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

# Initialize SGDClassifier
sgd_model = SGDClassifier(random_state=10)

# Initialize the RFE with SGDClassifier as the estimator
rfe = RFE(estimator=sgd_model, n_features_to_select=14)  # Select the top 14 features

# Fit RFE on the training data
rfe.fit(X_train, y_train)

# Get the names of the selected features
selected_features = X_train.columns[rfe.support_]
print(f"\nNumber of Selected Features: {len(selected_features)}")
print("Selected Features:")
print(selected_features)
# Out:
# Number of Selected Features: 14
# Selected Features:
# Index(['Gender', 'Country', 'Occupation', 'self_employed', 'family_history',
#        'Days_Indoors', 'Growing_Stress', 'Changes_Habits',
#        'Mental_Health_History', 'Coping_Struggles', 'Work_Interest',
#        'Social_Weakness', 'mental_health_interview', 'care_options'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, roc_auc_score

# %%
# Set up a pipeline with StandardScaler and SGDClassifier
pipeline = 
([
    ('scaler', StandardScaler()),
    ('sgd', SGDClassifier(random_state=42))
])

# Define the refined parameter grid for hyperparameter tuning for SGD
param_grid_sgd = {
    'sgd__loss': ['hinge', 'log_loss', 'modified_huber'],
    'sgd__penalty': ['l2', 'l1', 'elasticnet'],
    'sgd__alpha': [0.0001, 0.001, 0.01],
    'sgd__learning_rate': ['optimal', 'adaptive', 'invscaling'],
    'sgd__eta0': [0.01, 0.1]
}

# %%
# Initialize GridSearchCV for SGD
grid_search_sgd = GridSearchCV(pipeline, param_grid_sgd, cv=3, scoring='accuracy', n_jobs=-1, verbose=1)
grid_search_sgd.fit(X_train, y_train)

# Get the best SGD model and evaluate it
best_sgd_model = grid_search_sgd.best_estimator_
print("Best SGD hyperparameters:", grid_search_sgd.best_params_)
y_pred_sgd = best_sgd_model.predict(X_test)
print("Tuned SGD Classifier Accuracy:", accuracy_score(y_test, y_pred_sgd))
print("SGD Classification Report:\n", classification_report(y_test, y_pred_sgd))
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# Best SGD hyperparameters: {'sgd__alpha': 0.01, 'sgd__eta0': 0.01, 'sgd__learning_rate': 'optimal', 'sgd__loss': 'log_loss', 'sgd__penalty': 'l1'}
# Tuned SGD Classifier Accuracy: 0.702400037445733
# SGD Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70     42467
#            1       0.70      0.70      0.70     42990
#
#     accuracy                           0.70     85457
#    macro avg       0.70      0.70      0.70     85457
# weighted avg       0.70      0.70      0.70     85457

# %%
# Confusion Matrix and ROC for Tuned SGD Classifier
def plot_confusion_matrix(y_true, y_pred, model_name):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f'{model_name} Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

plot_confusion_matrix(y_test, y_pred_sgd, "Tuned SGD Classifier")

def plot_roc_curve(y_true, y_pred_prob, model_name):
    fpr, tpr, _ = roc_curve(y_true, y_pred_prob)
    auc_score = roc_auc_score(y_true, y_pred_prob)
    plt.figure(figsize=(6, 4))
    plt.plot(fpr, tpr, label=f'{model_name} (AUC = {auc_score:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'{model_name} ROC Curve')
    plt.legend(loc='best')
    plt.show()

# %%
# Plot ROC curve for the Tuned SGD Classifier
plot_roc_curve(y_test, best_sgd_model.decision_function(X_test), "Tuned SGD Classifier")

# Additional attempt with Gradient Boosting with Hyperparameter Tuning
# Define the parameter grid for Gradient Boosting
param_grid_gb = {
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [100, 150, 200],
    'max_depth': [3, 4, 5],
    'subsample': [0.8, 0.9, 1.0]
}

# %%
import matplotlib.pyplot as plt
import numpy as np

# Values for the table
models = ['Gradient Boosting', 'SGD Classifier']

accuracy = [0.775, 0.723]
precision_class_0 = [0.81, 0.74]
recall_class_0 = [0.71, 0.67]
f1_class_0 = [0.76, 0.71]
precision_class_1 = [0.75, 0.71]
recall_class_1 = [0.84, 0.77]
f1_class_1 = [0.79, 0.74]

# X-axis labels for each metric
metrics = ['Accuracy', 'Precision (Class 0)', 'Recall (Class 0)', 'F1-Score (Class 0)',
           'Precision (Class 1)', 'Recall (Class 1)', 'F1-Score (Class 1)']

# Arrange data for plotting
model_data = [accuracy, precision_class_0, recall_class_0, f1_class_0, precision_class_1, recall_class_1, f1_class_1]
x = np.arange(len(metrics))
width = 0.35  # Width of bars

# Create bar plot
fig, ax = plt.subplots(figsize=(12, 6))
bars1 = ax.bar(x - width/2, [data[0] for data in model_data], width, label='Gradient Boosting')
bars2 = ax.bar(x + width/2, [data[1] for data in model_data], width, label='SGD Classifier')

# Labels, title, and custom x-axis tick labels
ax.set_xlabel('Metrics')
ax.set_ylabel('Values')
ax.set_title('Comparison of Gradient Boosting and SGD Classifier Performance Metrics')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Add data labels on bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom')

add_labels(bars1)
add_labels(bars2)

plt.tight_layout()
plt.show()
